# %%
# !pip install -U langchain langchain-community -q

# %%
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter, RecursiveCharacterTextSplitter

# %%
# !wget https://www.gutenberg.org/cache/epub/2009/pg2009.txt -O research_article.txt

loader = TextLoader("research_article.txt")
documents = loader.load()
print(f"Document length: {len(documents[0].page_content)} characters")
# Out:
# --2025-07-26 12:47:05--  https://www.gutenberg.org/cache/epub/2009/pg2009.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1303047 (1.2M) [text/plain]
# Saving to: ‘research_article.txt’
#
# research_article.tx 100%[===================>]   1.24M  3.14MB/s    in 0.4s
#
# 2025-07-26 12:47:06 (3.14 MB/s) - ‘research_article.txt’ saved [1303047/1303047]
#
# Document length: 1276492 characters

# %%
fixed_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
chunks_fixed = fixed_splitter.split_documents(documents)
print(f"Fixed-size chunks: {len(chunks_fixed)}")
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 1287, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1528, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1184, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1971, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1081, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1908, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1701, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1868, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1114, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1120, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1071, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1039, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1557, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1428, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1283, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1449, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1332, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1864, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1279, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2770, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1277, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1950, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1443, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1892, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2261, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1779, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1082, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1011, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1554, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1674, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2519, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2543, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1517, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2563, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3112, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2437, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2198, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2183, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1578, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1353, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1324, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1796, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1979, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1670, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1819, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1474, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2130, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1970, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1749, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1798, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1478, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1488, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2445, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1111, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2277, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1385, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2873, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1207, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1901, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1215, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2630, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1491, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1133, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1027, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2340, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1503, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2068, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1513, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1092, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1279, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1078, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1404, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1772, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1329, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1406, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1040, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1076, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1728, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1656, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1775, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2372, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1436, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2712, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1774, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2295, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1731, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1919, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1202, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1103, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1076, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2435, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1557, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1508, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2009, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1995, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2145, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1418, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1532, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1719, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2459, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1498, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1395, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1648, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2499, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1279, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2050, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2705, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2903, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1383, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1685, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2358, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1212, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1271, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1374, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1081, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1934, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1289, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1611, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1676, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1534, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1637, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1371, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1228, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1346, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1259, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1901, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2247, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1462, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1275, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1178, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1814, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1068, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1267, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1241, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1096, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1165, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1254, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1351, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2450, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2250, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1156, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1829, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2025, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1308, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1926, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3414, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1388, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1145, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1666, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2215, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1601, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1318, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1621, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1171, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1554, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4106, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2436, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1743, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2266, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1381, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1115, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1943, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1036, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1425, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1510, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1448, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2796, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2369, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2090, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1974, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1787, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1196, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1865, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1463, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2039, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1738, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1925, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1256, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1601, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1856, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2034, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 4375, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1519, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1967, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1523, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2116, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1128, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1620, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1230, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1222, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1481, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1905, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1192, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1240, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1098, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1521, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1286, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2448, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1799, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1153, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1143, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1125, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1698, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1881, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2052, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1877, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3090, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1045, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1680, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2256, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2774, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1411, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1467, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1881, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2315, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2573, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2800, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1396, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1709, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1762, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1672, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1429, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1067, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1029, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1101, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1070, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1377, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1654, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1141, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1690, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2053, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2475, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2182, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1339, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2157, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1400, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2310, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1449, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1244, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1382, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1407, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2729, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1229, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1332, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1118, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1017, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1939, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1114, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1133, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1690, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1712, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1349, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2064, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2479, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1749, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2212, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1926, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1485, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1714, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1260, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1138, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1879, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1544, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1900, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1347, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2410, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1228, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1241, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1677, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1884, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2201, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1065, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1235, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1454, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1081, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1508, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1687, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1057, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1293, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2219, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2030, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2337, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1844, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1962, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2545, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1390, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1580, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2016, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2314, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1076, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1377, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2881, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1063, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1254, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1292, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1149, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1106, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2880, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1312, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1204, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1362, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1218, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1116, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2203, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1336, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1573, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3184, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1202, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2395, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1037, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1790, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1033, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1976, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1082, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2792, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1397, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1625, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1261, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1408, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2106, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1233, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2772, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1485, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1582, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1394, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1455, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1546, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1410, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1423, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1728, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1075, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1247, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1053, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2320, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1187, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1516, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2095, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3620, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1881, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1403, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1882, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1449, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1854, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2027, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1443, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1289, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2628, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1552, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1282, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1132, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1154, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1242, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1375, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1812, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1365, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1844, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1333, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1549, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1170, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1829, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1692, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2385, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2614, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1536, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1211, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1070, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1050, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2824, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1029, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2293, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1173, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2083, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1272, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1683, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1104, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1128, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1072, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1715, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1495, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2054, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1728, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1795, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1652, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2761, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1032, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2787, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1768, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1583, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2141, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1313, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1536, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1936, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2226, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1156, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1219, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1720, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1572, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1562, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1266, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1533, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1472, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1597, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2945, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1851, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1867, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1368, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1675, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1307, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1594, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1544, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3128, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1097, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1376, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1424, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1452, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1589, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2189, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1357, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1439, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1174, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1528, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1200, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1700, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2050, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1734, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1047, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1094, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2856, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2032, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1448, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1352, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3996, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3186, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1400, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1192, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2313, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1393, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1873, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1208, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2818, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1804, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1236, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1264, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1649, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2153, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1449, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1329, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1335, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1243, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2204, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1101, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1102, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1460, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1905, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1407, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2424, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1476, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1360, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1343, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1515, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2009, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1904, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1186, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1514, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1592, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3472, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1171, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1342, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1369, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2721, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1706, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1047, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2524, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2494, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1551, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2502, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3859, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1528, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2025, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1004, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2078, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1328, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2182, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1604, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2279, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1575, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2076, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1639, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1640, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1380, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1388, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3476, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1134, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1854, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1201, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1863, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1247, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1227, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1146, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1172, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2494, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2304, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1283, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1840, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1208, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2679, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1872, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2058, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1914, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1172, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1778, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1548, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1166, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1584, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1173, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2238, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1580, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1902, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1379, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1245, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1194, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1248, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1529, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1805, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1804, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1098, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2752, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2091, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2182, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1204, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1912, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1010, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1430, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1466, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1019, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1508, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1260, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1027, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1116, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2240, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1840, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1671, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1311, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3034, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1139, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1049, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1495, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1397, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1051, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1331, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1679, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1156, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1163, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1627, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1727, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1283, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2534, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2073, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1031, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1301, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1202, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1560, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1374, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1168, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2193, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1317, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2182, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1117, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1030, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1258, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1737, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1791, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1322, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1184, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1045, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1132, which is longer than the specified 1000
# WARNING:langchain_text_splitters.base:Created a chunk of size 1674, which is longer than the specified 1000
# Fixed-size chunks: 1026

# %%
import re

def sentence_split(doc, max_chars=1000):
    sentences = re.split(r'(?<=[.!?])\s+', doc.page_content)

    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) + 1 <= max_chars:
            current_chunk += " " + sentence
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

chunks_sentence = sentence_split(documents[0])
print(f"Sentence-based chunks: {len(chunks_sentence)}")
# Out:
# Sentence-based chunks: 1474

# %%
recursive_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""]
)
chunks_recursive = recursive_splitter.split_documents(documents)
print(f"Recursive chunks: {len(chunks_recursive)}")
# Out:
# Recursive chunks: 1845

# %%
def show_chunks(label, chunks, count=3):
    print(f"\n--- {label} ---")
    for i, chunk in enumerate(chunks[:count]):
        text = chunk.page_content if hasattr(chunk, 'page_content') else chunk
        print(f"Chunk {i+1}:\n{text[:500]}...\n{'-'*60}")

show_chunks("Fixed-size Chunking", chunks_fixed)
show_chunks("Sentence-based Chunking", chunks_sentence)
show_chunks("Recursive Chunking", chunks_recursive)
# Out:
# --- Fixed-size Chunking ---
# Chunk 1:
# ﻿The Project Gutenberg eBook of The Origin of Species by Means of Natural Selection
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are l...
# ------------------------------------------------------------
# Chunk 2:
# There are several editions of this ebook in the Project Gutenberg
# collection. Various characteristics of each ebook are listed to aid in
# selecting the preferred file.
# Click on any of the filenumbers below to quickly view each ebook.
#
# 1228    1859, First Edition
# 22764   1860, Second Edition
# 2009    1872, Sixth Edition, considered the definitive edition.
#
#
# On the Origin of Species
#
# BY MEANS OF NATURAL SELECTION,
#
# OR THE PRESERVATION OF FAVOURED RACES IN THE STRUGGLE FOR LIFE.
#
# By Charles Darwin, M...
# ------------------------------------------------------------
# Chunk 3:
# “The only distinct meaning of the word ‘natural’ is _stated_, _fixed_
# or _settled;_ since what is natural as much requires and presupposes an
# intelligent agent to render it so, _i.e._, to effect it continually or
# at stated times, as what is supernatural or miraculous does to effect
# it for once.”
#
# BUTLER: _Analogy of Revealed Religion_.
#
#
# “To conclude, therefore, let no man out of a weak conceit of sobriety,
# or an ill-applied moderation, think or maintain, that a man can search
# too far or be too ...
# ------------------------------------------------------------
#
# --- Sentence-based Chunking ---
# Chunk 1:
# ﻿The Project Gutenberg eBook of The Origin of Species by Means of Natural Selection
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are l...
# ------------------------------------------------------------
# Chunk 2:
# Various characteristics of each ebook are listed to aid in
# selecting the preferred file. Click on any of the filenumbers below to quickly view each ebook. 1228    1859, First Edition
# 22764   1860, Second Edition
# 2009    1872, Sixth Edition, considered the definitive edition. On the Origin of Species
#
# BY MEANS OF NATURAL SELECTION,
#
# OR THE PRESERVATION OF FAVOURED RACES IN THE STRUGGLE FOR LIFE. By Charles Darwin, M.A., F.R.S.,
#
# Author of “The Descent of Man,” etc., etc. Sixth London Edition, wit...
# ------------------------------------------------------------
# Chunk 3:
# “The only distinct meaning of the word ‘natural’ is _stated_, _fixed_
# or _settled;_ since what is natural as much requires and presupposes an
# intelligent agent to render it so, _i.e._, to effect it continually or
# at stated times, as what is supernatural or miraculous does to effect
# it for once.”
#
# BUTLER: _Analogy of Revealed Religion_. “To conclude, therefore, let no man out of a weak conceit of sobriety,
# or an ill-applied moderation, think or maintain, that a man can search
# too far or be too we...
# ------------------------------------------------------------
#
# --- Recursive Chunking ---
# Chunk 1:
# ﻿The Project Gutenberg eBook of The Origin of Species by Means of Natural Selection
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are l...
# ------------------------------------------------------------
# Chunk 2:
# Language: English
#
# Credits: Sue Asscher and David Widger
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK THE ORIGIN OF SPECIES BY MEANS OF NATURAL SELECTION ***
#
#
# There are several editions of this ebook in the Project Gutenberg
# collection. Various characteristics of each ebook are listed to aid in
# selecting the preferred file.
# Click on any of the filenumbers below to quickly view each ebook.
#
# 1228    1859, First Edition
# 22764   1860, Second Edition
# 2009    1872, Sixth Edition, considered the definit...
# ------------------------------------------------------------
# Chunk 3:
# By Charles Darwin, M.A., F.R.S.,
#
# Author of “The Descent of Man,” etc., etc.
#
# Sixth London Edition, with all Additions and Corrections.
#
#
#
#
# “But with regard to the material world, we can at least go so far as
# this—we can perceive that events are brought about not by insulated
# interpositions of Divine power, exerted in each particular case, but by
# the establishment of general laws.”
#
# WHEWELL: _Bridgewater Treatise_.
#
#
# “The only distinct meaning of the word ‘natural’ is _stated_, _fixed_
# or _settl...
# ------------------------------------------------------------

# %%
print(f"""
Summary of Chunking Results:
----------------------------
Fixed-size Chunking      → {len(chunks_fixed)} chunks
Sentence-based Chunking  → {len(chunks_sentence)} chunks
Recursive Chunking       → {len(chunks_recursive)} chunks
""")
# Out:
# Summary of Chunking Results:
# ----------------------------
# Fixed-size Chunking      → 1026 chunks
# Sentence-based Chunking  → 1474 chunks
# Recursive Chunking       → 1845 chunks
