# %%
# !pip install -q requests

# %%
import os
os.environ["GROQ_API_KEY"] = "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"

# %%
import requests

def summarize_article(article_text):
    api_key = os.getenv("GROQ_API_KEY")
    url = "https://api.groq.com/openai/v1/chat/completions"

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    messages = [
        {"role": "system", "content": "You are an expert research summarizer."},
        {"role": "user", "content": f"""
Summarize the following research article into a single paragraph of no more than 150 words.
It must include: background, objective, method, results, and key takeaways.

Article:
{article_text}
"""}
    ]

    payload = {
        "model": "llama3-8b-8192",
        "messages": messages,
        "temperature": 0.3,
        "max_tokens": 300
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code != 200:
        print("Error response:", response.text)
        response.raise_for_status()

    return response.json()['choices'][0]['message']['content'].strip()


test_article = "This is a short test article about cancer detection using AI."
summary = summarize_article(test_article)
print("Summary:\n", summary)
# Out:
# Summary:
#  I apologize, but the provided article is too short to summarize. However, I can provide a general outline of what a summary of this article could look like:
#
# Background: Cancer detection is a crucial task in the field of medicine, and the use of artificial intelligence (AI) has shown promising results in improving the accuracy and efficiency of this process.
#
# Objective: The objective of this study was to investigate the effectiveness of AI-based methods in detecting cancer from medical images.
#
# Method: The researchers used a dataset of medical images and trained an AI algorithm to identify patterns and features that are indicative of cancer.
#
# Results: The results showed that the AI algorithm was able to detect cancer with high accuracy, outperforming human radiologists in some cases.
#
# ...

# %%
import requests, os

response = requests.post(
    "https://api.groq.com/openai/v1/chat/completions",
    headers={
        "Authorization": f"Bearer {os.environ['GROQ_API_KEY']}",
        "Content-Type": "application/json"
    },
    json={
        "model": "llama3-8b-8192",
        "messages": [{"role": "user", "content": "Say hello in a formal tone"}],
        "temperature": 0.5
    }
)

print(response.json()['choices'][0]['message']['content'])
# Out:
# Good day to you.

# %%
import requests

def summarize_article(article_text):
    api_key = os.getenv("GROQ_API_KEY")
    url = "https://api.groq.com/openai/v1/chat/completions"

    prompt = f"""
You are an expert research summarizer.
Summarize the following research article into a single paragraph of no more than 150 words.
The summary must include:
1. Background and Introduction
2. Research Objective
3. Methodology
4. Results
5. Key Takeaways

Article:
\"\"\"
{article_text}
\"\"\"
Summary:
"""

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    payload = {
        "model": "llama3-8b-8192",  # You can use llama3-70b too
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.3,
        "max_tokens": 300
    }

    response = requests.post(url, headers=headers, json=payload)
    response.raise_for_status()
    return response.json()['choices'][0]['message']['content'].strip()

# %%
from google.colab import files

uploaded = files.upload()
filename = list(uploaded.keys())[0]

with open(filename, "r", encoding="utf-8") as f:
    article_text = f.read()
#article_text = "This is a short test article about cancer detection using AI."
summary = summarize_article(article_text)
print("Summary:\n")
print(summary)
# Out:
#      <input type="file" id="files-a84eab77-30cd-493c-a8d1-89b612b9824d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a84eab77-30cd-493c-a8d1-89b612b9824d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
